# %%
import numpy as np
import matplotlib.pyplot as plt

#Create training dataset


def spirals(n_points, noise=.5):
    n = np.sqrt(np.random.rand(n_points, 1)) * 720 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points, 1) * noise
    return (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))))


X = np.array(spirals(10000)[0])
Y = np.array(spirals(10000)[1])

spiral_1_x = (X[:10000, 0], X[:10000, 1])
spiral_1_y = (Y[:10000])
spiral_2_x = (X[10000:, 0], X[10000:, 1])
spiral_2_y = (Y[10000:])

#plot training dataset
plt.title('training set')
plt.plot(spiral_1_x[0], spiral_1_x[1], '.', label='class 1')
plt.plot(spiral_2_x[0], spiral_2_x[1], '.', label='class 2')
plt.legend()
plt.show()
# Out:
# (20000, 2)
# (20000,)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

#Create train, test dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)

#Find classifier with best parameters
svc = SVC()
param_grid = {'C': [0.1, 1, 10],
              'gamma': [0.1, 0.01, 0.001],
              'kernel': ('linear', 'rbf')}
              
grid = GridSearchCV(svc, param_grid, refit=True, verbose=3)
grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=  13.0s
# [CV 2/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=  12.1s
# [CV 3/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=  12.3s
# [CV 4/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=  11.4s
# [CV 5/5] END ................C=0.1, gamma=0.1, kernel=linear; total time=  11.5s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV 1/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=  11.5s
# [CV 2/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=  12.1s
# [CV 3/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=  11.9s
# [CV 4/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=  12.4s
# [CV 5/5] END ...............C=0.1, gamma=0.01, kernel=linear; total time=  12.0s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  14.5s
# [CV 2/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  14.3s
# [CV 3/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  14.7s
# [CV 4/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV 5/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  14.9s
# [CV 1/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=  13.4s
# [CV 2/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=  13.9s
# [CV 3/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=  12.3s
# [CV 4/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=  11.1s
# [CV 5/5] END ..............C=0.1, gamma=0.001, kernel=linear; total time=  11.2s
# [CV 1/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  14.3s
# [CV 2/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  16.7s
# [CV 3/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  16.2s
# [CV 4/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  15.9s
# [CV 5/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  15.0s
# [CV 1/5] END ..................C=1, gamma=0.1, kernel=linear; total time=  28.4s
# [CV 2/5] END ..................C=1, gamma=0.1, kernel=linear; total time=  23.3s
# [CV 3/5] END ..................C=1, gamma=0.1, kernel=linear; total time=  24.9s
# [CV 4/5] END ..................C=1, gamma=0.1, kernel=linear; total time=  26.6s
# [CV 5/5] END ..................C=1, gamma=0.1, kernel=linear; total time=  26.4s
# [CV 1/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 2/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 3/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 4/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 5/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 1/5] END .................C=1, gamma=0.01, kernel=linear; total time=  32.6s
# [CV 2/5] END .................C=1, gamma=0.01, kernel=linear; total time=  29.8s
# [CV 3/5] END .................C=1, gamma=0.01, kernel=linear; total time=  23.1s
# [CV 4/5] END .................C=1, gamma=0.01, kernel=linear; total time=  25.9s
# [CV 5/5] END .................C=1, gamma=0.01, kernel=linear; total time=  26.9s
# [CV 1/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV 2/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV 3/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV 4/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.5s
# [CV 5/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.8s
# [CV 1/5] END ................C=1, gamma=0.001, kernel=linear; total time=  26.5s
# [CV 2/5] END ................C=1, gamma=0.001, kernel=linear; total time=  24.5s
# [CV 3/5] END ................C=1, gamma=0.001, kernel=linear; total time=  24.0s
# [CV 4/5] END ................C=1, gamma=0.001, kernel=linear; total time=  29.3s
# [CV 5/5] END ................C=1, gamma=0.001, kernel=linear; total time=  26.1s
# [CV 1/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  15.5s
# [CV 2/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  16.0s
# [CV 3/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  14.0s
# [CV 4/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  14.2s
# [CV 5/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  14.5s
# [CV 1/5] END .................C=10, gamma=0.1, kernel=linear; total time= 1.5min
# [CV 2/5] END .................C=10, gamma=0.1, kernel=linear; total time= 1.5min
# [CV 3/5] END .................C=10, gamma=0.1, kernel=linear; total time= 1.6min
# [CV 4/5] END .................C=10, gamma=0.1, kernel=linear; total time= 1.4min
# [CV 5/5] END .................C=10, gamma=0.1, kernel=linear; total time= 1.4min
# [CV 1/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 2/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 3/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 4/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 5/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 1/5] END ................C=10, gamma=0.01, kernel=linear; total time= 1.4min
# [CV 2/5] END ................C=10, gamma=0.01, kernel=linear; total time= 1.5min
# [CV 3/5] END ................C=10, gamma=0.01, kernel=linear; total time= 1.5min
# [CV 4/5] END ................C=10, gamma=0.01, kernel=linear; total time= 1.4min
# [CV 5/5] END ................C=10, gamma=0.01, kernel=linear; total time= 1.4min
# [CV 1/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=  11.2s
# [CV 2/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=  11.8s
# [CV 3/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=  10.8s
# [CV 4/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=  11.7s
# [CV 5/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=  11.7s
# [CV 1/5] END ...............C=10, gamma=0.001, kernel=linear; total time= 1.6min
# [CV 2/5] END ...............C=10, gamma=0.001, kernel=linear; total time= 1.5min
# [CV 3/5] END ...............C=10, gamma=0.001, kernel=linear; total time= 1.6min
# [CV 4/5] END ...............C=10, gamma=0.001, kernel=linear; total time= 1.5min
# [CV 5/5] END ...............C=10, gamma=0.001, kernel=linear; total time= 1.5min
# [CV 1/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  16.1s
# [CV 2/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  15.2s
# [CV 3/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  15.2s
# [CV 4/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  14.7s
# [CV 5/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  16.5s
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=1, gamma=0.1)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)
    
#Classifier with best parameters
svc1 = SVC(C=1, gamma=0.1, kernel= 'rbf')
svc1.fit(X_train, y_train)
predicted = svc1.predict(X_test)

#Create 2 groups for plotting
spiral_1 = np.array([])
spiral_2 = np.array([])

for i in range(len(predicted)):
    if predicted[i] == 0:
        spiral_1 = np.append(spiral_1, X_test[i])
    else:
        spiral_2 = np.append(spiral_2, X_test[i])

spiral_1 = np.reshape(spiral_1, (-1, 2))
spiral_2 = np.reshape(spiral_2, (-1, 2))
plt.title('testing set')
plt.plot(spiral_1[:, np.array([0])],
         spiral_1[:, np.array([1])], '.', label='class 4')
plt.plot(spiral_2[:, np.array([0])],
         spiral_2[:, np.array([1])], '.', label='class 5')

# %%
from sklearn.metrics import accuracy_score

#Final accuracy
accuracy_score(y_test, predicted)
# Out:
# 1.0
